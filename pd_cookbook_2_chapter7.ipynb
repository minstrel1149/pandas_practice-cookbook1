# %%
import pandas as pd
import numpy as np
from pathlib import Path
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p1 = Path.cwd() / 'back_data'
movie = pd.read_csv(p1 / 'movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie.loc[:, ['duration']].head()
# Out:
#                                             duration
# movie_title
# Avatar                                         178.0
# Pirates of the Caribbean: At World's End       169.0
# Spectre                                        148.0
# The Dark Knight Rises                          164.0
# Star Wars: Episode VII - The Force Awakens       NaN

# %%
mv_2hours = movie.loc[:, ['duration']].dropna().gt(120)
movie.loc[:, ['duration']][mv_2hours].dropna()
# Out:
#                                                   duration
# movie_title
# Avatar                                               178.0
# Pirates of the Caribbean: At World's End             169.0
# Spectre                                              148.0
# The Dark Knight Rises                                164.0
# John Carter                                          132.0
# ...                                                    ...
# As It Is in Heaven                                   133.0
# Intolerance: Love's Struggle Throughout the Ages     123.0
# The Big Parade                                       151.0
# Ordet                                                126.0
# The Ridges                                           143.0
#
# [1039 rows x 1 columns]

# %%
actors = movie.loc[:, ['actor_1_facebook_likes', 'actor_2_facebook_likes']].dropna()
actors.assign(compare=actors.loc[:, 'actor_1_facebook_likes'].gt(actors.loc[:, 'actor_2_facebook_likes']))
# Out:
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                             actor_2_facebook_likes  compare
# movie_title
# ...

# %%
# and, or, not을 쓰면 객체 전체(Series 전체)의 truthiness를 찾으려고 시도 → 이치에 맞지 않고 개별 값의 True / False를 찾아야
# '&, |, ~' 등 비트별 연산자는 비교 연산자보다 우선순위가 높으므로 괄호 필요
criteria1 = movie.loc[:, 'imdb_score'] > 8
criteria2 = movie.loc[:, 'content_rating'] == 'PG-13'
criteria3 = (movie.loc[:, 'title_year'] < 2000) | (movie.loc[:, 'title_year'] > 2009)
criteria_final = criteria1 & criteria2 & criteria3
criteria_final.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
crit_a1 = movie.imdb_score > 8
crit_a2 = movie.content_rating == 'PG-13'
crit_a3 = (movie.title_year < 2000) | (movie.title_year > 2009)
final_crit_a = crit_a1 & crit_a2 & crit_a3
crit_b1 = movie.imdb_score < 5
crit_b2 = movie.content_rating == 'R'
crit_b3 = (movie.title_year >= 2000) & (movie.title_year <= 2010)
final_crit_b = crit_b1 & crit_b2 & crit_b3
final_crit_all = final_crit_a | final_crit_b
final_crit_all.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
movie.loc[final_crit_all, :].shape
# Out:
# (86, 27)

# %%
cols = ['imdb_score', 'content_rating', 'title_year']
movie_filtered = movie.loc[final_crit_all, cols]
movie_filtered.head()
# Out:
#                             imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises              8.5          PG-13      2012.0
# The Avengers                       8.1          PG-13      2012.0
# Captain America: Civil War         8.2          PG-13      2016.0
# Guardians of the Galaxy            8.1          PG-13      2014.0
# Interstellar                       8.6          PG-13      2014.0

# %%
college = pd.read_csv(p1 / 'college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
college.loc[college['STABBR'].eq('TX'), :].head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 3610        0.0         1     530.0     545.0           0.0  ...     0.0454
# 3611        0.0         0       NaN       NaN           0.0  ...     0.0002
# 3612        0.0         0       NaN       NaN           0.0  ...     0.0000
# 3613        0.0         0       NaN       NaN           0.0  ...     0.0264
# 3614        0.0         0     475.0     490.0           0.0  ...     0.0285
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
col2 = college.set_index('STABBR')
col2.loc['TX', :].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  UGDS_2MOR  \
# STABBR                                                      ...
# TX             1     530.0     545.0           0.0  3572.0  ...     0.0454
# TX             0       NaN       NaN           0.0  4682.0  ...     0.0002
# TX             0       NaN       NaN           0.0  9346.0  ...     0.0000
# TX             0       NaN       NaN           0.0  3825.0  ...     0.0264
# ...

# %%
states = ['TX', 'CA', 'NY']
college.loc[college['STABBR'].isin(states), :].shape, col2.loc[states, :].shape
# Out:
# ((1704, 27), (1704, 26))

# %%
col3 = col2.sort_index()
col3.head()
# Out:
#                                         INSTNM       CITY  HBCU  MENONLY  \
# STABBR
# AK                   Charter College-Anchorage  Anchorage   0.0      0.0
# AK                       Alaska Career College  Anchorage   0.0      0.0
# AK      AVTEC-Alaska's Institute of Technology     Seward   0.0      0.0
# AK                   Alaska Pacific University  Anchorage   0.0      0.0
# AK              University of Alaska Southeast     Juneau   0.0      0.0
#
#         WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  \
# STABBR                                                                 ...
# AK            0.0         0       NaN       NaN           0.0  3256.0  ...
# AK            0.0         0       NaN       NaN           0.0   479.0  ...
# AK            0.0         0       NaN       NaN           0.0   889.0  ...
# AK            0.0         1     555.0     503.0           0.0   275.0  ...
# ...

# %%
# %%timeit
col3.loc[states, :]
# Out:
# 378 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
col4 = college.set_index('INSTNM').sort_index()
col4.loc[['Stanford University'], :]
# Out:
#                          CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Stanford University  Stanford     CA   0.0      0.0        0.0         0
#
#                      SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  UGDS_2MOR  \
# INSTNM                                                         ...
# Stanford University     730.0     745.0           0.0  7018.0  ...     0.1067
#
#                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Stanford University    0.0819     0.0031       0.0         1   0.1556
#
#                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Stanford University    0.1256   0.0401            86000               12782
#
# [1 rows x 26 columns]

# %%
college.loc[college['INSTNM'].eq('Stanford University'), :]
# Out:
#                    INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4217  Stanford University  Stanford     CA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4217         0     730.0     745.0           0.0  ...     0.1067    0.0819
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4217     0.0031       0.0         1   0.1556    0.1256   0.0401
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4217            86000               12782
#
# [1 rows x 27 columns]

# %%
col5 = college.copy()
col5.index = col5.loc[:, 'CITY'] + ', ' + col5.loc[:, 'STABBR']
col5 = col5.sort_index()
col5.head()
# Out:
#                                  INSTNM      CITY STABBR  HBCU  MENONLY  \
# ARTESIA, CA           Angeles Institute   ARTESIA     CA   0.0      0.0
# Aberdeen, SD       Presentation College  Aberdeen     SD   0.0      0.0
# Aberdeen, SD  Northern State University  Aberdeen     SD   0.0      0.0
# Aberdeen, WA       Grays Harbor College  Aberdeen     WA   0.0      0.0
# Abilene, TX   Hardin-Simmons University   Abilene     TX   0.0      0.0
#
#               WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# ARTESIA, CA         0.0         0       NaN       NaN           0.0  ...
# Aberdeen, SD        0.0         1     440.0     480.0           0.0  ...
# Aberdeen, SD        0.0         0     480.0     475.0           0.0  ...
# Aberdeen, WA        0.0         0       NaN       NaN           0.0  ...
# Abilene, TX         0.0         1     508.0     515.0           0.0  ...
#
#               UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# ...

# %%
col5.loc['Miami, FL', :].head()
# Out:
#                                               INSTNM   CITY STABBR  HBCU  \
# Miami, FL        New Professions Technical Institute  Miami     FL   0.0
# Miami, FL               Management Resources College  Miami     FL   0.0
# Miami, FL                   Strayer University-Doral  Miami     FL   NaN
# Miami, FL                   Keiser University- Miami  Miami     FL   NaN
# Miami, FL  George T Baker Aviation Technical College  Miami     FL   0.0
#
#            MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
#
#            ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# ...

# %%
emp = pd.read_csv(p1 / 'employee.csv')
emp.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
depts = ['Houston Police Department-HPD', 'Houston Fire Department (HFD)']
select = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']
(emp
 .query("DEPARTMENT in @depts and GENDER == 'Female' and 80000 <= BASE_SALARY <= 120000")
 .loc[:, select]
)
# Out:
#       UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61           61  Houston Fire Department (HFD)  Female      96668.0
# 136         136  Houston Police Department-HPD  Female      81239.0
# 367         367  Houston Police Department-HPD  Female      86534.0
# 474         474  Houston Police Department-HPD  Female      91181.0
# 513         513  Houston Police Department-HPD  Female      81239.0
# 564         564  Houston Police Department-HPD  Female      81239.0
# 595         595  Houston Police Department-HPD  Female      99953.0
# 937         937  Houston Police Department-HPD  Female      81239.0
# 954         954  Houston Police Department-HPD  Female      91181.0
# 1118       1118  Houston Police Department-HPD  Female     104455.0
# 1519       1519  Houston Police Department-HPD  Female      91181.0
# 1565       1565  Houston Police Department-HPD  Female      81239.0
# 1622       1622  Houston Police Department-HPD  Female      91181.0

# %%
crit_dept = emp['DEPARTMENT'].isin(depts)
crit_gender = emp['GENDER'].eq('Female')
crit_sal = emp['BASE_SALARY'].between(80_000, 120_000, inclusive='both')
crit_final = crit_dept & crit_gender & crit_sal
emp.loc[crit_final, select]
# Out:
#       UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61           61  Houston Fire Department (HFD)  Female      96668.0
# 136         136  Houston Police Department-HPD  Female      81239.0
# 367         367  Houston Police Department-HPD  Female      86534.0
# 474         474  Houston Police Department-HPD  Female      91181.0
# 513         513  Houston Police Department-HPD  Female      81239.0
# 564         564  Houston Police Department-HPD  Female      81239.0
# 595         595  Houston Police Department-HPD  Female      99953.0
# 937         937  Houston Police Department-HPD  Female      81239.0
# 954         954  Houston Police Department-HPD  Female      91181.0
# 1118       1118  Houston Police Department-HPD  Female     104455.0
# 1519       1519  Houston Police Department-HPD  Female      91181.0
# 1565       1565  Houston Police Department-HPD  Female      81239.0
# 1622       1622  Houston Police Department-HPD  Female      91181.0

# %%
top_5_depts = emp['DEPARTMENT'].value_counts().index[:5]
criteria = ~emp['DEPARTMENT'].isin(top_5_depts)
emp.loc[criteria, select]
# Out:
#       UNIQUE_ID                   DEPARTMENT  GENDER  BASE_SALARY
# 0             0  Municipal Courts Department  Female     121862.0
# 1             1                      Library  Female      26125.0
# 4             4  General Services Department    Male      56347.0
# 18           18  General Services Department    Male      40581.0
# 32           32                      Finance    Male      46963.0
# ...         ...                          ...     ...          ...
# 1976       1976       Solid Waste Management  Female      34466.0
# 1983       1983   Admn. & Regulatory Affairs  Female      55172.0
# 1985       1985  Fleet Management Department    Male      30222.0
# 1988       1988             Legal Department    Male     124115.0
# 1990       1990           Parks & Recreation  Female      30347.0
#
# [419 rows x 4 columns]

# %%
(emp
 .query("DEPARTMENT not in @top_5_depts")
 .loc[:, select]
)
# Out:
#       UNIQUE_ID                   DEPARTMENT  GENDER  BASE_SALARY
# 0             0  Municipal Courts Department  Female     121862.0
# 1             1                      Library  Female      26125.0
# 4             4  General Services Department    Male      56347.0
# 18           18  General Services Department    Male      40581.0
# 32           32                      Finance    Male      46963.0
# ...         ...                          ...     ...          ...
# 1976       1976       Solid Waste Management  Female      34466.0
# 1983       1983   Admn. & Regulatory Affairs  Female      55172.0
# 1985       1985  Fleet Management Department    Male      30222.0
# 1988       1988             Legal Department    Male     124115.0
# 1990       1990           Parks & Recreation  Female      30347.0
#
# [419 rows x 4 columns]

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
fb_likes = movie.loc[:, 'actor_1_facebook_likes'].dropna()
fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
crit_high = fb_likes < 20_000
crit_low = fb_likes > 300
crit_high.mean().round(2), crit_low.mean().round(2)
# Out:
# (0.91, 0.88)

# %%
fig, ax = plt.subplots(figsize=(12, 3))
fb_likes.where(crit_high, 20_000).where(crit_low, 300).hist(bins=30, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(12, 3))
fb_likes.hist(bins=30, range=(300, 20_000), ax=ax)
# Out:
# <AxesSubplot:>

# %%
cols = ['content_rating', 'imdb_score', 'title_year', 'gross']
c1 = movie.loc[:, 'content_rating'].eq('G')
c2 = movie.loc[:, 'imdb_score'].lt(4)
criteria = c1 & c2

# %%
movie.loc[criteria, cols].sort_values('imdb_score')
# Out:
#                                content_rating  imdb_score  title_year  \
# movie_title
# Justin Bieber: Never Say Never              G         1.6      2011.0
# Sunday School Musical                       G         2.5      2008.0
# Doogal                                      G         2.8      2006.0
# Barney's Great Adventure                    G         2.8      1998.0
# The True Story of Puss'N Boots              G         2.9      2009.0
# Thomas and the Magic Railroad               G         3.6      2000.0
#
#                                      gross
# movie_title
# Justin Bieber: Never Say Never  73000942.0
# Sunday School Musical                  NaN
# Doogal                           7382993.0
# Barney's Great Adventure        11144518.0
# The True Story of Puss'N Boots         NaN
# Thomas and the Magic Railroad   15911333.0

# %%
col_index = [movie.columns.get_loc(col) for col in cols]
movie.iloc[criteria.to_numpy(), col_index].sort_values('imdb_score')
# Out:
#                                content_rating  imdb_score  title_year  \
# movie_title
# Justin Bieber: Never Say Never              G         1.6      2011.0
# Sunday School Musical                       G         2.5      2008.0
# Doogal                                      G         2.8      2006.0
# Barney's Great Adventure                    G         2.8      1998.0
# The True Story of Puss'N Boots              G         2.9      2009.0
# Thomas and the Magic Railroad               G         3.6      2000.0
#
#                                      gross
# movie_title
# Justin Bieber: Never Say Never  73000942.0
# Sunday School Musical                  NaN
# Doogal                           7382993.0
# Barney's Great Adventure        11144518.0
# The True Story of Puss'N Boots         NaN
# Thomas and the Magic Railroad   15911333.0
