# %%
import pandas as pd
import numpy as np
from pathlib import Path
import zipfile

# %%
p1 = Path.cwd() / 'back_data'
diamonds = pd.read_csv(p1 / 'diamonds.csv', nrows=1000)
diamonds
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 995   0.54    Ideal     D    VVS2   61.4   52.0   2897  5.30  5.34  3.26
# 996   0.72    Ideal     E     SI1   62.5   55.0   2897  5.69  5.74  3.57
# 997   0.72     Good     F     VS1   59.4   61.0   2897  5.82  5.89  3.48
# 998   0.74  Premium     D     VS2   61.8   58.0   2897  5.81  5.77  3.58
# 999   1.12  Premium     J     SI2   60.6   59.0   2898  6.68  6.61  4.03
#
# [1000 rows x 10 columns]

# %%
diamonds.memory_usage(deep=True)
# Out:
# Index        128
# carat       8000
# cut        63333
# color      58000
# clarity    60077
# depth       8000
# table       8000
# price       8000
# x           8000
# y           8000
# z           8000
# dtype: int64

# %%
with zipfile.ZipFile(p1 / 'kaggle-survey-2018.zip') as z:
    print('\n'.join(z.namelist()))
    kag = pd.read_csv(z.open('multipleChoiceResponses.csv'))
    kag_questions = kag.iloc[0, :]
    survey = kag.iloc[1:, :]
# Out:
# multipleChoiceResponses.csv
# freeFormResponses.csv
# SurveySchema.csv
# C:\Users\admin\AppData\Local\Temp\ipykernel_10664\3817102688.py:3: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open('multipleChoiceResponses.csv'))
